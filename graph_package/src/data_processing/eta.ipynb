# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/Users/johannesreiche/Library/Mobile Documents/com~apple~CloudDocs/DTU/MMC/Thesis/Code/GRLDrugProp/data/silver/oneil/oneil.csv")
data.drop('Unnamed: 0', axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    block_id        drug_row     drug_col cell_line_name study_name  \
# 0     16145  5-Fluorouracil    Veliparib        EFM192B      ONEIL
# 1     16146  5-Fluorouracil    Veliparib        EFM192B      ONEIL
# 2     16147  5-Fluorouracil    Veliparib        EFM192B      ONEIL
# 3     16148  5-Fluorouracil    Veliparib        EFM192B      ONEIL
# 4     16149  5-Fluorouracil      MK-1775        EFM192B      ONEIL
# 5     16150  5-Fluorouracil      MK-1775        EFM192B      ONEIL
# 6     16151  5-Fluorouracil      MK-1775        EFM192B      ONEIL
# 7     16152  5-Fluorouracil      MK-1775        EFM192B      ONEIL
# 8     16153  5-Fluorouracil  915019-65-7        EFM192B      ONEIL
# 9     16154  5-Fluorouracil  915019-65-7        EFM192B      ONEIL
#
#   tissue_name conc_row_unit conc_col_unit  ic50_row   ic50_col  ...   S_mean  \
# 0      breast            uM            uM      10.0  10.000000  ...  20.4610
# ...

# %%
drugA = data.drug_row
drugA[:10]
# Out:
# 0    5-Fluorouracil
# 1    5-Fluorouracil
# 2    5-Fluorouracil
# 3    5-Fluorouracil
# 4    5-Fluorouracil
# 5    5-Fluorouracil
# 6    5-Fluorouracil
# 7    5-Fluorouracil
# 8    5-Fluorouracil
# 9    5-Fluorouracil
# Name: drug_row, dtype: object

# %%
drugB = data.drug_col

# %%
pair_counts = data.groupby(['drug_row', 'drug_col']).size().reset_index(name='count')
pair_counts
# Out:
#         drug_row                        drug_col  count
# 0    391210-10-9  7-Ethyl-10-hydroxycamptothecin    156
# 1    391210-10-9                     891494-63-6    156
# 2    391210-10-9                     915019-65-7    156
# 3    391210-10-9                      Bortezomib    156
# 4    391210-10-9                       Dasatinib    156
# ..           ...                             ...    ...
# 578  vinorelbine                       Sunitinib    156
# 579  vinorelbine                       Veliparib    156
# 580  vinorelbine                      Vorinostat    156
# 581  vinorelbine                    geldanamycin    156
# 582  vinorelbine                    temozolomide    156
#
# [583 rows x 3 columns]

# %%
pair1 = data.loc[(data['drug_row'] == '5-Fluorouracil') & (data['drug_col'] == 'Veliparib')]

# %%
pair1
# Out:
#        block_id        drug_row   drug_col cell_line_name study_name  \
# 0         16145  5-Fluorouracil  Veliparib        EFM192B      ONEIL
# 1         16146  5-Fluorouracil  Veliparib        EFM192B      ONEIL
# 2         16147  5-Fluorouracil  Veliparib        EFM192B      ONEIL
# 3         16148  5-Fluorouracil  Veliparib        EFM192B      ONEIL
# 2416      27701  5-Fluorouracil  Veliparib           KPL1      ONEIL
# ...         ...             ...        ...            ...        ...
# 87547     64220  5-Fluorouracil  Veliparib        SKMEL30      ONEIL
# 89876     77981  5-Fluorouracil  Veliparib         UACC62      ONEIL
# 89877     77982  5-Fluorouracil  Veliparib         UACC62      ONEIL
# 89878     77983  5-Fluorouracil  Veliparib         UACC62      ONEIL
# 89879     77984  5-Fluorouracil  Veliparib         UACC62      ONEIL
#
#       tissue_name conc_row_unit conc_col_unit   ic50_row   ic50_col  ...  \
# ...

# %%
pair1.columns
# Out:
# Index(['block_id', 'drug_row', 'drug_col', 'cell_line_name', 'study_name',
#        'tissue_name', 'conc_row_unit', 'conc_col_unit', 'ic50_row', 'ic50_col',
#        'ri_row', 'ri_col', 'css_row', 'css_col', 'css_ri', 'S_sum', 'S_mean',
#        'S_max', 'synergy_zip', 'synergy_loewe', 'synergy_hsa', 'synergy_bliss',
#        'drug_row_clinical_phase', 'drug_col_clinical_phase',
#        'drug_row_target_name', 'drug_col_target_name'],
#       dtype='object')

# %%
pair1.cell_line_name.unique()
# Out:
# array(['EFM192B', 'KPL1', 'MDAMB436', 'OCUBM', 'T-47D', 'ZR751',
#        'COLO320DM', 'DLD1', 'HCT116', 'HT29', 'LOVO', 'RKO', 'SW-620',
#        'SW837', 'A427', 'MSTO', 'NCIH1650', 'NCIH2122', 'NCIH23',
#        'NCI-H460', 'NCIH520', 'SKMES1', 'A2780', 'CAOV3', 'ES2', 'OV90',
#        'OVCAR3', 'PA1', 'SK-OV-3', 'UWB1289', 'UWB1289+BRCA1', 'LNCAP',
#        'VCAP', 'A2058', 'A375', 'HT144', 'RPMI7951', 'SKMEL30', 'UACC62'],
#       dtype=object)

# %%
pair1.columns[8:22]
# Out:
# Index(['ic50_row', 'ic50_col', 'ri_row', 'ri_col', 'css_row', 'css_col',
#        'css_ri', 'S_sum', 'S_mean', 'S_max', 'synergy_zip', 'synergy_loewe',
#        'synergy_hsa', 'synergy_bliss'],
#       dtype='object')

# %%
pair1.iloc[:,8:22]
# Out:
#         ic50_row   ic50_col  ri_row  ri_col  css_row  css_col   css_ri  \
# 0      10.000000  10.000000  19.098  -1.661   23.201   35.158  29.1795
# 1      10.000000  10.000000  19.098  -1.661   16.258   30.871  23.5645
# 2      10.000000  10.000000  19.098  -1.661   23.611   40.580  32.0955
# 3      10.000000  10.000000  19.098  -1.661   19.803   33.467  26.6350
# 2416    8.055629   3.896132  22.529   5.580   29.098   41.526  35.3120
# ...          ...        ...     ...     ...      ...      ...      ...
# 87547   3.440874   1.937012  16.250  -1.645  -11.014  -15.466 -13.2400
# 89876   1.900106   0.035797  18.945  -4.039   14.243   20.868  17.5555
# 89877   1.900106   0.035797  18.945  -4.039   14.500   11.869  13.1845
# 89878   1.900106   0.035797  18.945  -4.039   19.573   21.573  20.5730
# 89879   1.900106   0.035797  18.945  -4.039   15.317   25.434  20.3755
#
#          S_sum   S_mean    S_max  synergy_zip  synergy_loewe  synergy_hsa  \
# ...

# %%
df = pd.read_csv("/Users/johannesreiche/Library/Mobile Documents/com~apple~CloudDocs/DTU/MMC/Thesis/Code/GRLDrugProp/data/bronze/drugcomb/summary_v_1_5.csv")
# Out:
# /Users/johannesreiche/Library/Mobile Documents/com~apple~CloudDocs/DTU/MMC/Thesis/Code/GRLDrugProp/myenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (2,7,19,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['block_id', 'drug_row', 'drug_col', 'cell_line_name', 'study_name',
#        'tissue_name', 'conc_row_unit', 'conc_col_unit', 'ic50_row', 'ic50_col',
#        'ri_row', 'ri_col', 'css_row', 'css_col', 'css_ri', 'S_sum', 'S_mean',
#        'S_max', 'synergy_zip', 'synergy_loewe', 'synergy_hsa', 'synergy_bliss',
#        'drug_row_clinical_phase', 'drug_col_clinical_phase',
#        'drug_row_target_name', 'drug_col_target_name'],
#       dtype='object')
